# %%
import pandas as pd

# %%
from datetime import date
from interactive_data_loader import load_kalshi_market
# Load market snapshots for a specific date range
df_market = load_kalshi_market(
    start_date=date(2021, 2, 20), 
    end_date=date(2030, 2, 22)
)

# %%
df_market.tail()
# Out:
#                         snapshot_ts_utc       event_ticker  \
# 532978 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532979 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532980 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532981 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532982 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
#
#                   market_ticker      subtitle  yes_bid  yes_ask  no_bid  \
# 532978    KXHIGHAUS-26FEB24-T73  72° or below      0.0      1.0    99.0
# 532979    KXHIGHAUS-26FEB24-T80  81° or above      0.0      1.0    99.0
# 532980  KXHIGHAUS-26FEB24-B77.5    77° to 78°      0.0      1.0    99.0
# 532981  KXHIGHAUS-26FEB24-B73.5    73° to 74°      0.0      1.0    99.0
# 532982  KXHIGHAUS-26FEB24-B75.5    75° to 76°     99.0    100.0     0.0
#
#         no_ask  last_price   volume  open_interest   trigger  is_data_live
# 532978   100.0         4.0  35080.0        26114.0  periodic          True
# 532979   100.0         1.0  11478.0         9770.0  periodic          True
# 532980   100.0        29.0  52202.0        24696.0  periodic          True
# 532981   100.0        16.0  41776.0        25246.0  periodic          True
# 532982     1.0        52.0  73034.0        29162.0  periodic          True

# %%
from datetime import date
from interactive_data_loader import load_kalshi_orderbook
# Load orderbook snapshots for a specific date range
# By default, reconstruct=True which builds the full limit order book
df_orderbook = load_kalshi_orderbook(
    start_date=date(2021, 2, 20), 
    end_date=date(2030, 2, 22)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_255533/1823901872.py in ?()
#       1 from datetime import date
#       2 from interactive_data_loader import load_kalshi_orderbook
#       3 # Load orderbook snapshots for a specific date range
#       4 # By default, reconstruct=True which builds the full limit order book
# ----> 5 df_orderbook = load_kalshi_orderbook(
#       6     start_date=date(2021, 2, 20),
#       7     end_date=date(2030, 2, 22)
#       8 )
#
# ~/projects/pred_market/research/interactive_data_loader.py in ?(start_date, end_date, reconstruct)
#      39     """Load Kalshi orderbook snapshots."""
#      40     from services.core.storage import ParquetStorage
#      41     storage = ParquetStorage(str(DATA_DIR))
#      42     if reconstruct:
# ---> 43         return storage.reconstruct_orderbooks(start_date, end_date)
#      44     return storage.read_parquets("orderbook", start_date, end_date)
#
# ~/projects/pred_market/services/core/storage.py in ?(self, start_date, end_date)
#     219         files = sorted(base.glob("*.parquet"))
#     220         if start_date:
#     221             files = [f for f in files if f.stem >= start_date.isoformat()]
#     222         if end_date:
# --> 223             files = [f for f in files if f.stem <= end_date.isoformat()]
#     224         if not files:
#     225             return pd.DataFrame()
#     226         return pa.concat_tables(
#
# ~/projects/pred_market/pred_env/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# ~/projects/pred_market/pred_env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'snapshot_ts'

# %%
df_orderbook.head()
# Out:
#                        snapshot_ts            market_ticker side  price_cents  \
# 0 2026-02-19 03:40:10.443637+00:00  KXHIGHCHI-26FEB19-B61.5  yes            2
# 1 2026-02-19 03:40:10.443637+00:00  KXHIGHCHI-26FEB19-B61.5  yes            1
# 2 2026-02-19 03:40:10.443637+00:00  KXHIGHCHI-26FEB19-B61.5   no           91
# 3 2026-02-19 03:40:10.443637+00:00  KXHIGHCHI-26FEB19-B61.5   no           94
# 4 2026-02-19 03:40:10.443637+00:00  KXHIGHCHI-26FEB19-B61.5   no           95
#
#    quantity  snapshot_type
# 0      59.0  reconstructed
# 1     258.0  reconstructed
# 2       3.0  reconstructed
# 3       7.0  reconstructed
# 4     326.0  reconstructed

# %%
from datetime import date
from interactive_data_loader import load_nwp_data
# Valid models: 'hrrr', 'nbm', 'rrfs'
df_hrrr = load_nwp_data(
    model="rrfs", 
    start_date=date(2021, 2, 20),
)

# %%
df_hrrr
# Out:
# Empty DataFrame
# Columns: []
# Index: []
