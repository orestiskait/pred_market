# %%
import pandas as pd

# %%
from datetime import date
from interactive_data_loader import load_kalshi_market
# Load market snapshots for a specific date range
df_market = load_kalshi_market(
    start_date=date(2021, 2, 20), 
    end_date=date(2030, 2, 22)
)

# %%
df_market.tail()
# Out:
#                             snapshot_ts       event_ticker  \
# 532978 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532979 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532980 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532981 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
# 532982 2026-02-25 04:30:37.373702+00:00  KXHIGHAUS-26FEB24
#
#                   market_ticker      subtitle  yes_bid  yes_ask  no_bid  \
# 532978    KXHIGHAUS-26FEB24-T73  72° or below        0        1      99
# 532979    KXHIGHAUS-26FEB24-T80  81° or above        0        1      99
# 532980  KXHIGHAUS-26FEB24-B77.5    77° to 78°        0        1      99
# 532981  KXHIGHAUS-26FEB24-B73.5    73° to 74°        0        1      99
# 532982  KXHIGHAUS-26FEB24-B75.5    75° to 76°       99      100       0
#
#         no_ask  last_price  volume  open_interest   trigger
# 532978     100           4   35080          26114  periodic
# 532979     100           1   11478           9770  periodic
# 532980     100          29   52202          24696  periodic
# 532981     100          16   41776          25246  periodic
# 532982       1          52   73034          29162  periodic

# %%
from datetime import date
from interactive_data_loader import load_nwp_data
# Valid models: 'hrrr', 'nbm', 'rrfs'
df_hrrr = load_nwp_data(
    model="hrrr", 
    start_date=date(2021, 2, 20),
)

# %%
df_hrrr
# Out:
#      station     city model                 cycle_utc  forecast_minutes  \
# 0       KMDW  Chicago  hrrr 2026-02-23 02:00:00+00:00               495
# 1       KMDW  Chicago  hrrr 2026-02-23 02:00:00+00:00               510
# 2       KMDW  Chicago  hrrr 2026-02-23 02:00:00+00:00               525
# 3       KMDW  Chicago  hrrr 2026-02-23 02:00:00+00:00               540
# 4       KMDW  Chicago  hrrr 2026-02-23 02:00:00+00:00               555
# ...      ...      ...   ...                       ...               ...
# 3593    KMDW  Chicago  hrrr 2026-02-25 03:00:00+00:00              1020
# 3594    KMDW  Chicago  hrrr 2026-02-25 03:00:00+00:00              1035
# 3595    KMDW  Chicago  hrrr 2026-02-25 03:00:00+00:00              1050
# 3596    KMDW  Chicago  hrrr 2026-02-25 03:00:00+00:00              1065
# 3597    KMDW  Chicago  hrrr 2026-02-25 03:00:00+00:00              1080
#
#                      valid_utc    tmp_2m_k   tmp_2m_f  grid_lat  grid_lon  \
# 0    2026-02-23 10:15:00+00:00  265.260000  17.800000   41.7809  -87.7722
